# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Chargement des données et visualisation
#
# Voici les données qu'Hubble a compilées :

# %%
hubble_df = pd.read_csv("hubble_data.csv") # charge les données du fichier Hubble.csv
print(hubble_df)
# Out:
#     distance  recession_velocity
# 0      0.032                 170
# 1      0.034                 290
# 2      0.214                -130
# 3      0.263                 -70
# 4      0.275                -185
# 5      0.275                -220
# 6      0.450                 200
# 7      0.500                 290
# 8      0.500                 270
# 9      0.630                 200
# 10     0.800                 300
# 11     0.900                 -30
# 12     0.900                 650
# 13     0.900                 150
# 14     0.900                 500
# 15     1.000                 920
# 16     1.100                 450
# 17     1.100                 500
# 18     1.400                 500
# 19     1.700                 960
# 20     2.000                 500
# 21     2.000                 850
# 22     2.000                 800
# 23     2.000                1090

# %% [markdown]
# Les voici représentées en un nuage de points :

# %%
plt.title("Données Hubble 1929\n (éloignement des galaxies en fonction\n \
de leur distance à la terre)",fontweight="bold",fontsize=13)
plt.xlabel("distance (pc)")
plt.ylabel("vitesse (km/s)")
x = np.array(hubble_df["distance"].values)
x1 = x[:,np.newaxis]
y = np.array(hubble_df["recession_velocity"].values)
plot = plt.scatter(x,y,s=50,color='b',edgecolors='k',)

# %% [markdown]
# Créons maintenant un modèle de la répartition de ces données grâce à une régression linéaire (moindres carrés) sur l'ensemble des données disponibles :

# %%
regr = linear_model.LinearRegression() # Create linear regression object
x1 = x[:, np.newaxis]
y1 = y[:, np.newaxis]
regr.fit(x1, y1) # Train the model using the training sets
y_pred = regr.predict(x1) # Make predictions using the testing set

plt.title("Données Hubble 1929\n (éloignement des galaxies en fonction\n \
de leur distance à la terre)",fontweight="bold",fontsize=13)
plt.xlabel("distance (pc)")
plt.ylabel("vitesse (km/s)")

plt.scatter(x1,y1, s=250,color='y',edgecolors='k', label='données',zorder=10)
plt.plot(x,y_pred, color='blue', linewidth=3, label='régression linéaire',zorder=5)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, s=25,color='y',edgecolors='k', label='données')
plt.plot(x,y_pred,'-s', color='blue', linewidth=3)#), label='régression linéaire')
plt.legend()
plt.title("Données divisées en deux parties homogènes", fontsize=12, fontweight="bold")
plt.show()

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred,'-s', color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
