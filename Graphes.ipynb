# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
### Graphes simples

fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
### Personalisations diverses

# Chanegr la taille de police par défaut
plt.rcParams.update({'font.size': 15})

fig = plt.figure()
ax = plt.axes()
# Couleur spécifiée par son nom, ligne solide
plt.plot(x, np.sin(x - 0), color='blue', linestyle='solid', label='bleu')
# Nom court pour la couleur, ligne avec des traits
plt.plot(x, np.sin(x - 1), color='g', linestyle='dashed', label='vert')
# Valeur de gris entre 0 et 1, des traits et des points
plt.plot(x, np.sin(x - 2), color='0.75', linestyle='dashdot', label='gris')
# Couleur spécifié en RGB, avec des points
plt.plot(x, np.sin(x - 3), color='#FF0000', linestyle='dotted', label='rouge')

# Les limites des axes, essayez aussi les arguments 'tight' et 'equal' 
# pour voir leur effet
plt.axis([-1, 11, -1.5, 1.5]);

# Les labels
plt.title("Un exemple de graphe")

# La légende est générée à partir de l'argument label de la fonctio
# plot. L'argument loc spécifie le placement de la légende
plt.legend(loc='lower left');

# Titres des axes
ax = ax.set(xlabel='x', ylabel='sin(x)')

# %%
###  Sous-graphiques 

figure = plt.figure()

# graphe pour 10 parties
plot1 = plt.subplot(1, 3, 1)
plt.title("10 parties (courbe)",fontweight="bold")
plt.xlabel("numéro de la partie")
plot1.yaxis.set_major_locator(plt.MaxNLocator(1))
plot1.axis([-1, 11, 0, 1])
plot1.yaxis.set_ticklabels(["Perdu","Gagné"])
plot1.plot(np.arange(10),1/(np.arange(10)+1), color = 'blue')

# graphe pour 10000 parties (courbe)
plot2 = plt.subplot(1, 3, 2)
plt.title("10 000 parties (courbe)",fontweight="bold")
plt.xlabel("numéro de la partie")
plot2.plot(np.arange(10),np.arange(10)^2, color = 'red')

# graphe pour 10000 parties (nuage de point)
plot3 = plt.subplot(1, 3, 3)
plt.title("10 000 parties (nuage de points)",fontweight="bold")
plt.xlabel("numéro de la partie")
plot3.scatter(np.arange(10),np.arange(10)^3, color = 'g')

# gestion des marges
plt.gcf().subplots_adjust(left = 0, bottom = 0.2, right = 3, top = 0.9, wspace = 0.2, hspace = 0.2)

# %%
### Graphes en barres

plt.title("Comparaison des stratégies",fontweight="bold")
plt.xlabel("numéro de la partie")
plt.ylabel("pourcentage de parties gagnées (%)")
plot = plt.bar([1,2,3],[10,50,20], tick_label=["Garder", "Changer", "Aléatoire"], color = 'blue')
plot.axis.set_major_locator(ticker.MultipleLocator(1.00))
plot.axis.set_minor_locator(ticker.MultipleLocator(0.25))
#plot.xaxis.set_major_formatter(ticker.PercentFormatter(xmax=5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-012d0b3588ab> in <module>()
#       5 plt.ylabel("pourcentage de parties gagnées (%)")
#       6 plot = plt.bar([1,2,3],[10,50,20], tick_label=["Garder", "Changer", "Aléatoire"], color = 'blue')
# ----> 7 plot.axis.set_major_locator(ticker.MultipleLocator(1.00))
#       8 plot.axis.set_minor_locator(ticker.MultipleLocator(0.25))
#       9 #plot.xaxis.set_major_formatter(ticker.PercentFormatter(xmax=5))
#
# AttributeError: 'BarContainer' object has no attribute 'axis'

# %%
### Personnalisations plus poussées de graphes en barres

x = np.random.randn(1000)

plt.style.use('classic')
fig=plt.figure(figsize=(5,3))
ax = plt.axes(facecolor='#E6E6E6')

# Afficher les ticks en dessous de l'axe
ax.set_axisbelow(True)

# Cadre en blanc
plt.grid(color='w', linestyle='solid')

# Cacher le cadre
# ax.spines contient les lignes qui entourent la zone où les 
# données sont affichées.
for spine in ax.spines.values():
    spine.set_visible(False)
    
# Cacher les marqueurs en haut et à droite
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()

# Nous pouvons personnaliser les étiquettes des marqueurs
# et leur appliquer une rotation
marqueurs = [-3, -2, -1, 0, 1, 2, 3]
xtick_labels = ['A', 'B', 'C', 'D', 'E', 'F']
plt.xticks(marqueurs, xtick_labels, rotation=30)

# Changer les couleur des marqueurs
ax.tick_params(colors='gray', direction='out')
for tick in ax.get_xticklabels():
    tick.set_color('gray')
for tick in ax.get_yticklabels():
    tick.set_color('gray')
    
# Changer les couleur des barres
ax.hist(x, edgecolor='#E6E6E6', color='#EE6666');

# %%
import matplotlib.pyplot as plt
import numpy as np
#import seaborn as sns

### barres d'erreur

x = np.linspace(0, 10, 50)
dy = 2
y = np.sin(x)
ybis = np.sin(x) + dy * np.random.randn(50) # randn : bruit gaussien ; rand : uniforme

plt.rcParams.update({'font.size': 15})

fig = plt.figure()
ax = plt.axes()
#plt.plot(x, y, color='blue', linestyle='solid', label='sin non bruité')
plt.plot(x, y, c='blue', linestyle='solid', label='sin non bruité')
plt.plot(x, ybis, c='r', linestyle='dotted', label='sin bruité')
plt.errorbar(x, ybis, yerr=dy, fmt='o', color='black', ecolor='lightgray', elinewidth=3, capsize=0 , label='bruit');

plt.axis('tight'); #'equal'
plt.title("Un exemple de graphe")
plt.legend(loc='lower left');
plt.grid(True)

ax = ax.set(xlabel='x', ylabel='y = sin(x)')

# %%
### différents styles seaborn

print(plt.style.available[:6]) # affiche le nom des six styles disponibles
# Notez la taille de la figure
fig = plt.figure(figsize=(12,8))
for i in range(6):
    # On peut ajouter des sous graphes ainsi
    fig.add_subplot(3,2,i+1)
    plt.style.use(plt.style.available[i])
    plt.plot(x, y)
    
    # Pour ajouter du texte
    plt.text(s=plt.style.available[i], x=5, y=2, color='red')
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot']

# %%
import seaborn as sns

sns.set()

x = np.linspace(0, 10, 500)
y = np.random.randn(500)
plt.plot(x,y)

# %%
sns.distplot(y, kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
iris = sns.load_dataset("iris")
iris.head()
# Pour voir les relations entre ces caractéristiques, on peut faire des graphiques par paire 
sns.pairplot(iris, hue='species', size=2.5);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# distribution jointe de deux caractéristiques

with sns.axes_style('white'):
    sns.jointplot("petal_length", "petal_width", data=iris, kind='reg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# remettre des données dans l'ordre facilement

import itertools

#x = [3, 5, 6, 1, 2]
#y = [6, 7, 8, 9, 10]
x = np.random.rand(48)
y = np.random.rand(48)

# apparemment, izip n'existerait plus...
#lists = sorted(itertools.izip(*[x, y]))
#new_x, new_y = list(itertools.izip(*lists))

new_x, new_y = zip(*sorted(zip(x, y)))

figure = plt.figure()

# Avant
p1 = plt.subplot(1, 3, 1)
plt.title("AVANT", fontweight="bold")
plt.xlabel("x")
plt.ylabel("y")
p1.plot(x,y, 'o-', color = 'red', label='désordre !')
plt.legend()

# Après
p2 = plt.subplot(1, 3, 2)
plt.title("APRES", fontweight="bold")
plt.xlabel("x triés")
plt.ylabel("y triés")
p2.plot(new_x, new_y,'s-', color = 'blue', label='ordre !')
plt.axis('tight')
plt.legend()

# Ensemble
p3 = plt.subplot(1, 3, 3)
plt.title("ENSEMBLE", fontweight="bold")
plt.xlabel("x triés")
plt.ylabel("y triés")
a1, = p3.plot(x,y, 'o', color = 'red',markerfacecolor = 'k', markersize = 5, \
            markeredgecolor='red', markeredgewidth=1, linestyle = 'dotted', \
              label='désordre !', zorder = 100) # zorder élevé pour mettre la courbe au-dessus 
a2, = p3.plot(new_x, new_y, color = 'blue', label='ordre !', zorder = 15)
plt.axis('tight')
plt.legend(handles=[a2,a1]).set_zorder(100) # pour gérer l'ordre des
                        # lignes de la légende ET remettre la légende au-dessus !

plt.show()
